# %%
# IMPORT MODULES

# %matplotlib inline

import datetime
import time
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as dts
import calendar

import pandas as pd

# %%
# READ DATA
data = pd.read_csv("data_compteurgeneral_second_2015_09.csv")
data["Date & Time"] = pd.to_datetime(data["Date & Time"])

#print(data.dtypes)
#print(data.describe())
data.plot()

#http://pandas.pydata.org/pandas-docs/stable/timeseries.html
#http://pandas.pydata.org/pandas-docs/version/0.16.2/timeseries.html
# Out:
#           Date & Time  use [kW]  gen [kW]  Power Phase1 [kW]  \
# 0 2015-09-29 23:59:00  0.344967        -0            0.24245
#
#    Power Phase2 [kW]  Power Phase 3 [kW]  Intensity Phase1 [A]  \
# 0           0.062933            0.039583              1.479833
#
#    Intensity Phase2 [A]  Intensity Phase3 [A]  Main Circuit Breaker [kW]
# 0                0.6558                   0.5                   0.344967
